# %%
from cadastrar import cadastrar_aluno

from media import calcular_media

from verificar import verificar_situacao
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       1 from cadastrar import cadastrar_aluno
#       3 from media import calcular_media
# ----> 5 from verificar import verificar_situacao
#
# ImportError: cannot import name 'verificar_situacao' from 'verificar' (c:\Users\52624930\Documents\GitHub\sistema_notas\verificar.py)

# %%
nome, nota1, nota2 = cadastrar_aluno()
media = calcular_media(nota1, nota2)
situacao = verificar_situacao(media)

print("\n===== RESULTADO =====")
print(f"Aluno: {nome}")
print(f"Média: {media:.1f}")
print(f"Situação: {situacao}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from cadastrar import cadastrar_aluno
# ----> 2 from media import calcular_media
#       3 from verificar import verificar_situacao
#       6 nome, nota1, nota2 = cadastrar_aluno()
#
# ImportError: cannot import name 'calcular_media' from 'media' (c:\Users\52624930\Documents\GitHub\sistema_notas\media.py)
